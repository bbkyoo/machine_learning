# %%
import pymysql

# 2. 접속하기
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='rb3879181', db='best_ranking', charset='utf8')

# 3. 커서 가져오기
cursor = db.cursor()


import requests
from bs4 import BeautifulSoup

url ="https://search.musinsa.com/category/003007"

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
res = requests.get(url, headers = headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")
items=soup.find_all("li", {"class":"li_box"})

print("★★cotton_pants★★")
count=0;
for item in items:
    cotton_pants_p_no=item['data-no']
    print(cotton_pants_p_no)
    
    cotton_pants_p_name=item.find('a',{'name':'goods_link'})['title']
    print(cotton_pants_p_name)
    
    if(item.find('p',{'class':'price'}).find('del')==None):
        cotton_pants_ori_price=int(item.find('p',{'class':'price'}).get_text().strip().strip("원").replace(",",""))
        print(cotton_pants_ori_price)
    else:
        cotton_pants_ori_price=int(item.find('p',{'class':'price'}).find('del').get_text().strip().strip("원").replace(",",""))
        print(cotton_pants_ori_price)

        cotton_pants_sale_price=int(item.find('p',{'class':'price'}).find('del').next_sibling.strip().strip("원").replace(",",""))
        print(cotton_pants_sale_price)
    
    cotton_pants_comments=int(item.find('span',{'class':'count'}).get_text().replace(",",""))
    print(cotton_pants_comments)
    
    if(item.find('p',{'class':'price'}).find('del')==None):
        sql = """
        INSERT INTO cotton_pants VALUES(
        {}, "{}", {}, NULL, {});""".format(cotton_pants_p_no,cotton_pants_p_name,cotton_pants_ori_price,cotton_pants_comments)
        
    else:
        sql = """
        INSERT INTO cotton_pants VALUES(
        {}, "{}", {}, {}, {});""".format(cotton_pants_p_no,cotton_pants_p_name,cotton_pants_ori_price,cotton_pants_sale_price,cotton_pants_comments)
    
    # 5. SQL 구문 실행하기
    cursor.execute(sql)

    # 6. commit 하기
    db.commit()
    
    print("*"*100)
    count+=1
    if count==10:
        break
    
    
url ="https://search.musinsa.com/category/003008"

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edg/91.0.864.67"}
res = requests.get(url, headers = headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")
items=soup.find_all("li", {"class":"li_box"})

print("\n★slacks★\n")
count=0;
for item in items:
    slacks_p_no=item['data-no']
    print(slacks_p_no)
    
    slacks_p_name=item.find('a',{'name':'goods_link'})['title']
    print(slacks_p_name)
    
    if(item.find('p',{'class':'price'}).find('del')==None):
        slacks_ori_price=int(item.find('p',{'class':'price'}).get_text().strip().strip("원").replace(",",""))
        print(slacks_ori_price)
    else:
        slacks_ori_price=int(item.find('p',{'class':'price'}).find('del').get_text().strip().strip("원").replace(",",""))
        print(slacks_ori_price)

        slacks_sale_price=int(item.find('p',{'class':'price'}).find('del').next_sibling.strip().strip().strip("원").replace(",",""))
        print(slacks_sale_price)
        
    
    
    slacks_comments=int(item.find('span',{'class':'count'}).get_text().replace(",",""))
    print(slacks_comments)
    
    if(item.find('p',{'class':'price'}).find('del')==None):
        sql = """
        INSERT INTO slacks VALUES(
        {}, "{}", {}, NULL, {});""".format(slacks_p_no,slacks_p_name,slacks_ori_price,slacks_comments)
        
    else:
        sql = """
        INSERT INTO slacks VALUES(
        {}, "{}", {}, {}, {});""".format(slacks_p_no,slacks_p_name,slacks_ori_price,slacks_sale_price,slacks_comments)
    
    # 5. SQL 구문 실행하기
    cursor.execute(sql)

    # 6. commit 하기
    db.commit()
    
    
    print("*"*100)
    count+=1
    if count==10:
        break
    
    
url ="https://search.musinsa.com/category/003004"

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edg/91.0.864.67"}
res = requests.get(url, headers = headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")
items=soup.find_all("li", {"class":"li_box"})

print("\n★training_pants★\n")
count=0;
for item in items:
    training_pants_p_no=item['data-no']
    print(training_pants_p_no)
    
    training_pants_p_name=item.find('a',{'name':'goods_link'})['title']
    print(training_pants_p_name)
    
    if(item.find('p',{'class':'price'}).find('del')==None):
        training_pants_ori_price=int(item.find('p',{'class':'price'}).get_text().strip().strip("원").replace(",",""))
        print(training_pants_ori_price)
    else:
        training_pants_ori_price=int(item.find('p',{'class':'price'}).find('del').get_text().strip().strip("원").replace(",",""))
        print(training_pants_ori_price)

        training_pants_sale_price=int(item.find('p',{'class':'price'}).find('del').next_sibling.strip().strip().strip("원").replace(",",""))
        print(training_pants_sale_price)
        
     
    training_pants_comments=int(item.find('span',{'class':'count'}).get_text().replace(",",""))
    print(training_pants_comments)
 
    if(item.find('p',{'class':'price'}).find('del')==None):
        sql = """
        INSERT INTO training_pants VALUES(
        {}, "{}", {}, NULL, {});""".format(training_pants_p_no,training_pants_p_name,training_pants_ori_price,training_pants_comments)
        
    else:
        sql = """
        INSERT INTO training_pants VALUES(
        {}, "{}", {}, {}, {});""".format(training_pants_p_no,training_pants_p_name,training_pants_ori_price,training_pants_sale_price,training_pants_comments)
    
    # 5. SQL 구문 실행하기
    cursor.execute(sql)

    # 6. commit 하기
    db.commit()

    print("*"*100)
    count+=1
    if count==10:
        break
    
    
url ="https://search.musinsa.com/category/003009"

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edg/91.0.864.67"}
res = requests.get(url, headers = headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")
items=soup.find_all("li", {"class":"li_box"})

print("\n★short_pants★\n")
count=0;
for item in items:
    short_pants_p_no=item['data-no']
    print(short_pants_p_no)
    
    short_pants_p_name=item.find('a',{'name':'goods_link'})['title']
    print(short_pants_p_name)
    
    if(item.find('p',{'class':'price'}).find('del')==None):
        short_pants_ori_price=int(item.find('p',{'class':'price'}).get_text().strip().strip("원,").replace(",",""))
        print(short_pants_ori_price)
    else:
        short_pants_ori_price=int(item.find('p',{'class':'price'}).find('del').get_text().strip().strip("원,").replace(",",""))
        print(short_pants_ori_price)

        short_pants_sale_price=int(item.find('p',{'class':'price'}).find('del').next_sibling.strip().strip().strip("원,").replace(",",""))
        print(short_pants_sale_price)
 
    short_pants_comments=int(item.find('span',{'class':'count'}).get_text().replace(",",""))
    print(short_pants_comments)
    
    if(item.find('p',{'class':'price'}).find('del')==None):
        sql = """
        INSERT INTO short_pants VALUES(
        {}, "{}", {}, NULL, {});""".format(short_pants_p_no,short_pants_p_name,short_pants_ori_price,short_pants_comments)
        
    else:
        sql = """
        INSERT INTO short_pants VALUES(
        {}, "{}", {}, {}, {});""".format(short_pants_p_no,short_pants_p_name,short_pants_ori_price,short_pants_sale_price,short_pants_comments)
    
    # 5. SQL 구문 실행하기
    cursor.execute(sql)

    # 6. commit 하기
    db.commit()
    
    print("*"*100)
    count+=1
    if count==10:
        break

# 7. DB 연결 닫기
db.close()
# Out:
# ★★cotton_pants★★
# 1931720
# 테이퍼드 와이드 원턱 린넨 팬츠_Oatmeal
# 36000
# 29800
# 2510
# ****************************************************************************************************
# 1931526
# 테이퍼드 와이드 원턱 린넨 팬츠_Martine Olive
# 36000
# 29800
# 2352
# ****************************************************************************************************
# 1931537
# 테이퍼드 와이드 원턱 린넨 팬츠_Black
# 36000
# 29800
# 1249
# ****************************************************************************************************
# 380217
# [세트상품] 린넨 9부 밴딩 팬츠
# 80000
# 32800
# 10934
# ****************************************************************************************************
# 1924274
# 린넨 세미 와이드 밴딩 팬츠 세트
# 66000
# 42900
# 1241
# ****************************************************************************************************
# 1636775
# [패키지] 플레인(여름용) 코튼 밴딩팬츠 2PACK CJLP7509
# 63800
# 49100
# 2870
# ...

# %%
import pymysql

# 2. 접속하기
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='rb3879181', db='best_ranking', charset='utf8')

# 3. 커서 가져오기
cursor = db.cursor()

# %%
# 4. SQL 구문 만들기 (CRUD SQL 구문 등)
sql = """
CREATE TABLE cotton_pants (
    p_num INT NOT NULL,
    p_name VARCHAR(100) NOT NULL,
    ori_price INT,
    sale_price INT,
    comments INT,
    PRIMARY KEY(p_num)
);
"""

# 5. SQL 구문 실행하기
cursor.execute(sql)

# 6. DB에 Complete 하기
db.commit()

# %%
sql = """
CREATE TABLE slacks (
    p_num INT NOT NULL,
    p_name VARCHAR(100) NOT NULL,
    ori_price INT,
    sale_price INT,
    comments INT,
    PRIMARY KEY(p_num)
);

"""
# 5. SQL 구문 실행하기
cursor.execute(sql)

# 6. DB에 Complete 하기
db.commit()

# %%
sql="""
CREATE TABLE training_pants (
    p_num INT NOT NULL,
    p_name VARCHAR(100) NOT NULL,
    ori_price INT,
    sale_price INT,
    comments INT,
    PRIMARY KEY(p_num)
);
"""

# 5. SQL 구문 실행하기
cursor.execute(sql)

# 6. DB에 Complete 하기
db.commit()

# %%
sql="""
CREATE TABLE short_pants (
    p_num INT NOT NULL,
    p_name VARCHAR(100) NOT NULL,
    ori_price INT,
    sale_price INT,
    comments INT,
    PRIMARY KEY(p_num)
);
"""

# 5. SQL 구문 실행하기
cursor.execute(sql)

# 6. DB에 Complete 하기
db.commit()

# 7. DB 연결 닫기
db.close()
