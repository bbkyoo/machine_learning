# %%
import requests
from bs4 import BeautifulSoup
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='rb3879181', db='best_ranking', charset='utf8')
musinsa = db.cursor()
sql = """
    CREATE TABLE shot_tshirts (
        p_num int NOT NULL,
        p_name VARCHAR(100) not null,
        ori_price INT not null, 
        sale_price INT,
        comments INT,
        PRIMARY KEY(p_num)
    );
"""

musinsa.execute(sql)

url ="https://search.musinsa.com/category/001001"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
res = requests.get(url, headers=headers)
res.raise_for_status()


soup = BeautifulSoup(res.text, "lxml")

shot_tshirts_names = soup.find_all('p', {"class":"list_info"})
shot_tshirts_nums = soup.find_all('li', {"class":"li_box"})
shot_tshirts_prices = soup.find_all('p', {"class":"price"})
shot_tshirts_comments = soup.find_all('span', {"class":"count"})

for i in range(10):
    shot_tshirts_num = int(shot_tshirts_nums[i]['data-no'])
    shot_tshirts_name = shot_tshirts_names[i].find('a',{'name': 'goods_link'})['title']
    shot_tshirts_ori_price = None
    shot_tshirts_sale_price = None
    shot_tshirts_comment = shot_tshirts_comments[i].get_text()
    
    if ',' in shot_tshirts_comment:
        shot_tshirts_comment = shot_tshirts_comment.replace(',','')
    shot_tshirts_comment = int(shot_tshirts_comment)
    
    sql = ''
    if shot_tshirts_prices[i].find('del'):
        shot_tshirts_ori_price = shot_tshirts_prices[i].get_text().split()[0]
        shot_tshirts_sale_price = shot_tshirts_prices[i].get_text().split()[1]
        if ',' in shot_tshirts_ori_price:
            shot_tshirts_ori_price = shot_tshirts_ori_price.replace(',','')
        if ',' in shot_tshirts_sale_price:
            shot_tshirts_sale_price = shot_tshirts_sale_price.replace(',','')
        shot_tshirts_ori_price = int(shot_tshirts_ori_price[:-1])
        shot_tshirts_sale_price = int(shot_tshirts_sale_price[:-1])   
        sql = """INSERT INTO shot_tshirts VALUES({}, "{}", {}, {}, {});""".format(shot_tshirts_num, shot_tshirts_name, shot_tshirts_ori_price, shot_tshirts_sale_price, shot_tshirts_comment)         
    else:
        shot_tshirts_ori_price = shot_tshirts_prices[i].get_text().strip()
        if ',' in shot_tshirts_ori_price:
            shot_tshirts_ori_price = shot_tshirts_ori_price.replace(',','')
        shot_tshirts_ori_price = int(shot_tshirts_ori_price[:-1])
        sql = """INSERT INTO shot_tshirts VALUES({}, "{}", {}, NULL, {});""".format(shot_tshirts_num, shot_tshirts_name, shot_tshirts_ori_price, shot_tshirts_comment)    
 
    musinsa.execute(sql)
    
db.commit()
db.close()

# %%
import requests
from bs4 import BeautifulSoup
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='rb3879181', db='best_ranking', charset='utf8')
musinsa = db.cursor()
sql = """
    CREATE TABLE shirts (
        p_num int NOT NULL,
        p_name VARCHAR(100) not null,
        ori_price INT not null, 
        sale_price INT,
        comments INT,
        PRIMARY KEY(p_num)
    );
"""

musinsa.execute(sql)

url ="https://search.musinsa.com/category/001002"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
res = requests.get(url, headers=headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

shirts_names = soup.find_all('p', {"class":"list_info"})
shirts_nums = soup.find_all('li', {"class":"li_box"})
shirts_prices = soup.find_all('p', {"class":"price"})
shirts_comments = soup.find_all('span', {"class":"count"})

for i in range(10):
    shirts_num = int(shirts_nums[i]['data-no'])
    shirts_name = shirts_names[i].find('a',{'name': 'goods_link'})['title']
    shirts_ori_price = None
    shirts_sale_price = None
    shirts_comment = shirts_comments[i].get_text()
    
    if ',' in shirts_comment:
        shirts_comment = shirts_comment.replace(',','')
    shirts_comment = int(shirts_comment)
    
    sql = ''
    if shirts_prices[i].find('del'):
        shirts_ori_price = shirts_prices[i].get_text().split()[0]
        shirts_sale_price = shirts_prices[i].get_text().split()[1]
        if ',' in shirts_ori_price:
            shirts_ori_price = shirts_ori_price.replace(',','')
        if ',' in shirts_sale_price:
            shirts_sale_price = shirts_sale_price.replace(',','')
        shirts_ori_price = int(shirts_ori_price[:-1])
        shirts_sale_price = int(shirts_sale_price[:-1])   
        sql = """INSERT INTO shirts VALUES({}, "{}", {}, {}, {});""".format(shirts_num, shirts_name, shirts_ori_price, shirts_sale_price, shirts_comment)         
    else:
        shirts_ori_price = shirts_prices[i].get_text().strip()
        if ',' in shirts_ori_price:
            shirts_ori_price = shirts_ori_price.replace(',','')
        shirts_ori_price = int(shirts_ori_price[:-1])
        sql = """INSERT INTO shirts VALUES({}, "{}", {}, NULL, {});""".format(shirts_num, shirts_name, shirts_ori_price, shirts_comment)    
 
    musinsa.execute(sql)
    
db.commit()
db.close()

# %%
import requests
from bs4 import BeautifulSoup
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='rb3879181', db='best_ranking', charset='utf8')
musinsa = db.cursor()
sql = """
    CREATE TABLE collar_tshirts (
        p_num int NOT NULL,
        p_name VARCHAR(100) not null,
        ori_price INT not null, 
        sale_price INT,
        comments INT,
        PRIMARY KEY(p_num)
    );
"""

musinsa.execute(sql)

url ="https://search.musinsa.com/category/001003"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
res = requests.get(url, headers=headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

collar_tshirts_names = soup.find_all('p', {"class":"list_info"})
collar_tshirts_nums = soup.find_all('li', {"class":"li_box"})
collar_tshirts_prices = soup.find_all('p', {"class":"price"})
collar_tshirts_comments = soup.find_all('span', {"class":"count"})

for i in range(10):
    collar_tshirts_num = int(collar_tshirts_nums[i]['data-no'])
    collar_tshirts_name = collar_tshirts_names[i].find('a',{'name': 'goods_link'})['title']
    collar_tshirts_ori_price = None
    collar_tshirts_sale_price = None
    collar_tshirts_comment = collar_tshirts_comments[i].get_text()
    
    if ',' in collar_tshirts_comment:
        collar_tshirts_comment = collar_tshirts_comment.replace(',','')
    collar_tshirts_comment = int(collar_tshirts_comment)
    
    sql = ''
    if collar_tshirts_prices[i].find('del'):
        collar_tshirts_ori_price = collar_tshirts_prices[i].get_text().split()[0]
        collar_tshirts_sale_price = collar_tshirts_prices[i].get_text().split()[1]
        if ',' in collar_tshirts_ori_price:
            collar_tshirts_ori_price = collar_tshirts_ori_price.replace(',','')
        if ',' in collar_tshirts_sale_price:
            collar_tshirts_sale_price = collar_tshirts_sale_price.replace(',','')
        collar_tshirts_ori_price = int(collar_tshirts_ori_price[:-1])
        collar_tshirts_sale_price = int(collar_tshirts_sale_price[:-1])   
        sql = """INSERT INTO collar_tshirts VALUES({}, "{}", {}, {}, {});""".format(collar_tshirts_num, collar_tshirts_name, collar_tshirts_ori_price, collar_tshirts_sale_price, collar_tshirts_comment)         
    else:
        collar_tshirts_ori_price = collar_tshirts_prices[i].get_text().strip()
        if ',' in collar_tshirts_ori_price:
            collar_tshirts_ori_price = collar_tshirts_ori_price.replace(',','')
        collar_tshirts_ori_price = int(collar_tshirts_ori_price[:-1])
        sql = """INSERT INTO collar_tshirts VALUES({}, "{}", {}, NULL, {});""".format(collar_tshirts_num, collar_tshirts_name, collar_tshirts_ori_price, collar_tshirts_comment)    
 
    musinsa.execute(sql)
    
db.commit()
db.close()

# %%
import requests
from bs4 import BeautifulSoup
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='rb3879181', db='best_ranking', charset='utf8')
musinsa = db.cursor()
sql = """
    CREATE TABLE denim_pants (
        p_num int NOT NULL,
        p_name VARCHAR(100) not null,
        ori_price INT not null, 
        sale_price INT,
        comments INT,
        PRIMARY KEY(p_num)
    );
"""

musinsa.execute(sql)

url ="https://search.musinsa.com/category/003002"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
res = requests.get(url, headers=headers)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")

denim_pants_names = soup.find_all('p', {"class":"list_info"})
denim_pants_nums = soup.find_all('li', {"class":"li_box"})
denim_pants_prices = soup.find_all('p', {"class":"price"})
denim_pants_comments = soup.find_all('span', {"class":"count"})

for i in range(10):
    denim_pants_num = int(denim_pants_nums[i]['data-no'])
    denim_pants_name = denim_pants_names[i].find('a',{'name': 'goods_link'})['title']
    denim_pants_ori_price = None
    denim_pants_sale_price = None
    denim_pants_comment = denim_pants_comments[i].get_text()
    
    if ',' in denim_pants_comment:
        denim_pants_comment = denim_pants_comment.replace(',','')
    denim_pants_comment = int(denim_pants_comment)
    
    sql = ''
    if denim_pants_prices[i].find('del'):
        denim_pants_ori_price = denim_pants_prices[i].get_text().split()[0]
        denim_pants_sale_price = denim_pants_prices[i].get_text().split()[1]
        if ',' in denim_pants_ori_price:
            denim_pants_ori_price = denim_pants_ori_price.replace(',','')
        if ',' in denim_pants_sale_price:
            denim_pants_sale_price = denim_pants_sale_price.replace(',','')
        denim_pants_ori_price = int(denim_pants_ori_price[:-1])
        denim_pants_sale_price = int(denim_pants_sale_price[:-1])   
        sql = """INSERT INTO denim_pants VALUES({}, "{}", {}, {}, {});""".format(denim_pants_num, denim_pants_name, denim_pants_ori_price, denim_pants_sale_price, denim_pants_comment)         
    else:
        denim_pants_ori_price = denim_pants_prices[i].get_text().strip()
        if ',' in denim_pants_ori_price:
            denim_pants_ori_price = denim_pants_ori_price.replace(',','')
        denim_pants_ori_price = int(denim_pants_ori_price[:-1])
        sql = """INSERT INTO collar_tshirts VALUES({}, "{}", {}, NULL, {});""".format(denim_pants_num, denim_pants_name, denim_pants_ori_price, denim_pants_comment)    
 
    musinsa.execute(sql)
    
db.commit()
db.close()
